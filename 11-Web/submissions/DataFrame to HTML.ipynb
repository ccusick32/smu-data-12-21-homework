# %%
import pandas as pd

# %%
path = "../submissions/Resources/weather_data.csv"
df = pd.read_csv(path)

df.head()
# Out:
#         city Country  Latitude  Longitude  Temperature        Date  \
# 0      Kapaa      US   22.0752  -159.3190        76.89  1644441062
# 1    Rikitea      PF  -23.1203  -134.9692        79.00  1644441062
# 2  Cape Town      ZA  -33.9258    18.4232        68.54  1644441062
# 3       Hilo      US   19.7297  -155.0900        74.79  1644441062
# 4     Nushki      PK   29.5542    66.0215        48.31  1644441062
#
#    wind_Speed  Pressure  Humidity  Cloudiness
# 0        5.99    1018.0      68.0        25.0
# 1       15.26    1020.0      68.0         0.0
# 2        1.14    1014.0      79.0         0.0
# 3        3.44    1019.0      72.0       100.0
# 4        2.19    1021.0      29.0         0.0

# %%
df.to_html(index=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>city</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Date</th>\n      <th>wind_Speed</th>\n      <th>Pressure</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Kapaa</td>\n      <td>US</td>\n      <td>22.0752</td>\n      <td>-159.3190</td>\n      <td>76.89</td>\n      <td>1644441062</td>\n      <td>5.99</td>\n      <td>1018.0</td>\n      <td>68.0</td>\n      <td>25.0</td>\n    </tr>\n    <tr>\n      <td>Rikitea</td>\n      <td>PF</td>\n      <td>-23.1203</td>\n      <td>-134.9692</td>\n      <td>79.00</td>\n      <td>1644441062</td>\n      <td>15.26</td>\n      <td>1020.0</td>\n      <td>68.0</td>\n      <td>0.0</td>\n    </tr>\n    <tr>\n      <td>Cape Town</td>\n      <td>ZA</td>\n      <td>-33.9258</td>\n      <td>18.4232</td>\n      <td>68.54</td>\n     
# ...
